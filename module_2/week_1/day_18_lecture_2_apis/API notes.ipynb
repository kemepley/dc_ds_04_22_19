# %% [markdown]
# # APIs and Python

# %% [markdown]
# ## The Many Use Cases for APIs
# APIs can actually be used for many things - not just for retrieving information. Twilio has an API that allows you to write a script to call their API to send text messages to people. GitHub has an API for creating new repositories. Many services have an API allowing a computer to automate a task that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ### _Learning Goals:_<br/>
#   - Identify and discuss APIs
#   - Discuss and explain different request (GET, POST, PUT, DELETE) and CRUD operations
#   - Explore the attributes of a response object
#   - Check the status of a request and interpret status codes
#   - Access data from an API using the requests library
#   - Create a pandas dataframe from the data returned from an API and visualize the data
#   - If time, target an API of their own!!!

# %% [markdown]
# ## Limitations of APIs
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.

# %% [markdown]
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information through their API.

# %% [markdown]
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.

# %% [markdown]
# Let's take a look at the `requests` library and it's uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# ![img-req](requests-pic.jpeg)
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ![nongmao](requests_med.png)
#
# "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor. "<br>
# [More requests documentation](https://2.python-requests.org//en/v0.10.6/api/)

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# !pip install requests

# %% [markdown]
# ### Types of requests
#
# We will mostly use GET, but there are other options
#
# Let's say you are looking at an API for a car rental company like Hertz, or maybe even Zipcar.
#
# The following different requests will generate these different responses.
#
# |Request        | Result        |
# |-------------|-------------|
# |GET /stores/   | User sees the list of stores|
# |GET /rentals/  | User sees the history of car rentals|
# |POST /rentals/ | User rents a car|
# |PUT /rentals/{id}/| User changes destination store|
# |DELETE /rentals/{id}/| User cancels the active car rental|

# %%
rental_json = [{
    "id": 1,
    "name": "John St",
    "location": [29, 95],
    "available_cars_quantity": 10
},
{
    "id": 2,
    "name": "Scott St.",
    "location": [29.5, 95.7],
    "available_cars_quantity": 2
}]

# %%
#create a post request from https://httpbin.org/post and view it in json format

r = requests.post('http://httpbin.org/post', data={'key':'value'}) #put url and data = {'key':'value'} format here in the bananas!
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0'},
#  'json': None,
#  'origin': '65.207.79.74, 65.207.79.74',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ### Request Class and Attributes

# %%
#create a GET request from https://api.github.com/events and view it in json format

r = requests.get('https://api.github.com/events') #put url here in the bananas!
type(r)
# Out:
# requests.models.Response

# %% [markdown]
# Let's check the `attributes` of a `Response` object. <br>
# https://2.python-requests.org//en/v0.10.6/api/
#
# Some key attributes:
#
# - url
# - text
# - status_code
# - headers
# - error

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Wed, 15 May 2019 18:45:52 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '2', 'X-RateLimit-Reset': '1557946825', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept', 'ETag': 'W/"aaf084aa4226135594ef5fb6b155ca56"', 'Last-Modified': 'Wed, 15 May 2019 18:40:52 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'A775:44B1:6B765B:DC76D9:5CDC5E60'}

# %%
r.json()
# Out:
# [{'id': '9633454028',
#   'type': 'DeleteEvent',
#   'actor': {'id': 22753882,
#    'login': 'smithki',
#    'display_login': 'smithki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smithki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22753882?'},
#   'repo': {'id': 176424786,
#    'name': 'smithki/storage-proxy',
#    'url': 'https://api.github.com/repos/smithki/storage-proxy'},
#   'payload': {'ref': 'fix-defaults',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z'},
#  {'id': '9633454024',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23979,
#    'login': 'gaurav',
#    'display_login': 'gaurav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gaurav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23979?'},
#   'repo': {'id': 106746274,
#    'name': 'phyloref/curation-tool',
#    'url': 'https://api.github.com/repos/phyloref/curation-tool'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/phyloref/curation-tool/issues/122',
#     'repository_url': 'https://api.github.com/repos/phyloref/curation-tool',
#     'labels_url': 'https://api.github.com/repos/phyloref/curation-tool/issues/122/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/phyloref/curation-tool/issues/122/comments',
#     'events_url': 'https://api.github.com/repos/phyloref/curation-tool/issues/122/events',
#     'html_url': 'https://github.com/phyloref/curation-tool/issues/122',
#     'id': 387974921,
#     'node_id': 'MDU6SXNzdWUzODc5NzQ5MjE=',
#     'number': 122,
#     'title': 'Provide the ability to validate PHYX files',
#     'user': {'login': 'gaurav',
#      'id': 23979,
#      'node_id': 'MDQ6VXNlcjIzOTc5',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/23979?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gaurav',
#      'html_url': 'https://github.com/gaurav',
#      'followers_url': 'https://api.github.com/users/gaurav/followers',
#      'following_url': 'https://api.github.com/users/gaurav/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gaurav/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gaurav/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gaurav/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gaurav/orgs',
#      'repos_url': 'https://api.github.com/users/gaurav/repos',
#      'events_url': 'https://api.github.com/users/gaurav/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gaurav/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2018-12-05T22:31:28Z',
#     'updated_at': '2019-05-15T18:40:52Z',
#     'closed_at': '2019-05-15T18:40:52Z',
#     'author_association': 'MEMBER',
#     'body': "We don't currently validate PHYX files -- unexpected content is simply ignored, and malformed expressions will result in a JavaScript error. Instead, we should look into validating PHYX files, either in the Curation Tool or on the command line. [JSON Schema](https://json-schema.org/) might be one way to do this. It would also be useful for the Clade Ontology if PHYX files could be distinguished from other JSON files, such as by including a particular `@context` or `@type` annotation."},
#    'comment': {'url': 'https://api.github.com/repos/phyloref/curation-tool/issues/comments/492775085',
#     'html_url': 'https://github.com/phyloref/curation-tool/issues/122#issuecomment-492775085',
#     'issue_url': 'https://api.github.com/repos/phyloref/curation-tool/issues/122',
#     'id': 492775085,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDQ5Mjc3NTA4NQ==',
#     'user': {'login': 'gaurav',
#      'id': 23979,
#      'node_id': 'MDQ6VXNlcjIzOTc5',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/23979?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gaurav',
#      'html_url': 'https://github.com/gaurav',
#      'followers_url': 'https://api.github.com/users/gaurav/followers',
#      'following_url': 'https://api.github.com/users/gaurav/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gaurav/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gaurav/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gaurav/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gaurav/orgs',
#      'repos_url': 'https://api.github.com/users/gaurav/repos',
#      'events_url': 'https://api.github.com/users/gaurav/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gaurav/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-05-15T18:40:52Z',
#     'updated_at': '2019-05-15T18:40:52Z',
#     'author_association': 'MEMBER',
#     'body': 'Moved to phyloref/phyx.js#16, closing it here.'}},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z',
#   'org': {'id': 19719335,
#    'login': 'phyloref',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/phyloref',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19719335?'}},
#  {'id': '9633454023',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 11215289,
#    'login': 'keksobot',
#    'display_login': 'keksobot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keksobot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11215289?'},
#   'repo': {'id': 180440600,
#    'name': 'htmlacademy-php/128700-doingsdone-9',
#    'url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9'},
#   'payload': {'action': 'closed',
#    'number': 13,
#    'pull_request': {'url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/13',
#     'id': 278831133,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc4ODMxMTMz',
#     'html_url': 'https://github.com/htmlacademy-php/128700-doingsdone-9/pull/13',
#     'diff_url': 'https://github.com/htmlacademy-php/128700-doingsdone-9/pull/13.diff',
#     'patch_url': 'https://github.com/htmlacademy-php/128700-doingsdone-9/pull/13.patch',
#     'issue_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues/13',
#     'number': 13,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Вход на\xa0сайт',
#     'user': {'login': 'YuliaGutkina',
#      'id': 16776075,
#      'node_id': 'MDQ6VXNlcjE2Nzc2MDc1',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/16776075?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/YuliaGutkina',
#      'html_url': 'https://github.com/YuliaGutkina',
#      'followers_url': 'https://api.github.com/users/YuliaGutkina/followers',
#      'following_url': 'https://api.github.com/users/YuliaGutkina/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/YuliaGutkina/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/YuliaGutkina/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/YuliaGutkina/subscriptions',
#      'organizations_url': 'https://api.github.com/users/YuliaGutkina/orgs',
#      'repos_url': 'https://api.github.com/users/YuliaGutkina/repos',
#      'events_url': 'https://api.github.com/users/YuliaGutkina/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/YuliaGutkina/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '\n\n---\n:mortar_board: [Вход на\xa0сайт](https://up.htmlacademy.ru/php/9/user/128700/tasks/15)',
#     'created_at': '2019-05-14T20:04:08Z',
#     'updated_at': '2019-05-15T18:40:52Z',
#     'closed_at': '2019-05-15T18:40:52Z',
#     'merged_at': '2019-05-15T18:40:52Z',
#     'merge_commit_sha': '9cf36912466d64736a5f31209aa84e27238eb3df',
#     'assignee': {'login': 'AntonTrekov',
#      'id': 4680327,
#      'node_id': 'MDQ6VXNlcjQ2ODAzMjc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/4680327?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AntonTrekov',
#      'html_url': 'https://github.com/AntonTrekov',
#      'followers_url': 'https://api.github.com/users/AntonTrekov/followers',
#      'following_url': 'https://api.github.com/users/AntonTrekov/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AntonTrekov/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AntonTrekov/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AntonTrekov/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AntonTrekov/orgs',
#      'repos_url': 'https://api.github.com/users/AntonTrekov/repos',
#      'events_url': 'https://api.github.com/users/AntonTrekov/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AntonTrekov/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'AntonTrekov',
#       'id': 4680327,
#       'node_id': 'MDQ6VXNlcjQ2ODAzMjc=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/4680327?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AntonTrekov',
#       'html_url': 'https://github.com/AntonTrekov',
#       'followers_url': 'https://api.github.com/users/AntonTrekov/followers',
#       'following_url': 'https://api.github.com/users/AntonTrekov/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AntonTrekov/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AntonTrekov/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AntonTrekov/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AntonTrekov/orgs',
#       'repos_url': 'https://api.github.com/users/AntonTrekov/repos',
#       'events_url': 'https://api.github.com/users/AntonTrekov/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AntonTrekov/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/13/commits',
#     'review_comments_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/13/comments',
#     'review_comment_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues/13/comments',
#     'statuses_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/statuses/719135dcf088de1771addc7162436b59615fda81',
#     'head': {'label': 'YuliaGutkina:module7-task2',
#      'ref': 'module7-task2',
#      'sha': '719135dcf088de1771addc7162436b59615fda81',
#      'user': {'login': 'YuliaGutkina',
#       'id': 16776075,
#       'node_id': 'MDQ6VXNlcjE2Nzc2MDc1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/16776075?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/YuliaGutkina',
#       'html_url': 'https://github.com/YuliaGutkina',
#       'followers_url': 'https://api.github.com/users/YuliaGutkina/followers',
#       'following_url': 'https://api.github.com/users/YuliaGutkina/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/YuliaGutkina/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/YuliaGutkina/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/YuliaGutkina/subscriptions',
#       'organizations_url': 'https://api.github.com/users/YuliaGutkina/orgs',
#       'repos_url': 'https://api.github.com/users/YuliaGutkina/repos',
#       'events_url': 'https://api.github.com/users/YuliaGutkina/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/YuliaGutkina/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 181028906,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODEwMjg5MDY=',
#       'name': '128700-doingsdone-9',
#       'full_name': 'YuliaGutkina/128700-doingsdone-9',
#       'private': False,
#       'owner': {'login': 'YuliaGutkina',
#        'id': 16776075,
#        'node_id': 'MDQ6VXNlcjE2Nzc2MDc1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/16776075?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/YuliaGutkina',
#        'html_url': 'https://github.com/YuliaGutkina',
#        'followers_url': 'https://api.github.com/users/YuliaGutkina/followers',
#        'following_url': 'https://api.github.com/users/YuliaGutkina/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/YuliaGutkina/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/YuliaGutkina/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/YuliaGutkina/subscriptions',
#        'organizations_url': 'https://api.github.com/users/YuliaGutkina/orgs',
#        'repos_url': 'https://api.github.com/users/YuliaGutkina/repos',
#        'events_url': 'https://api.github.com/users/YuliaGutkina/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/YuliaGutkina/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/YuliaGutkina/128700-doingsdone-9',
#       'description': 'Юлия Гуткина',
#       'fork': True,
#       'url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9',
#       'forks_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/forks',
#       'keys_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/teams',
#       'hooks_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/hooks',
#       'issue_events_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/events',
#       'assignees_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/tags',
#       'blobs_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/languages',
#       'stargazers_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/stargazers',
#       'contributors_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/contributors',
#       'subscribers_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/subscribers',
#       'subscription_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/subscription',
#       'commits_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/merges',
#       'archive_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/downloads',
#       'issues_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/YuliaGutkina/128700-doingsdone-9/deployments',
#       'created_at': '2019-04-12T14:53:41Z',
#       'updated_at': '2019-05-14T05:24:44Z',
#       'pushed_at': '2019-05-15T18:36:39Z',
#       'git_url': 'git://github.com/YuliaGutkina/128700-doingsdone-9.git',
#       'ssh_url': 'git@github.com:YuliaGutkina/128700-doingsdone-9.git',
#       'clone_url': 'https://github.com/YuliaGutkina/128700-doingsdone-9.git',
#       'svn_url': 'https://github.com/YuliaGutkina/128700-doingsdone-9',
#       'homepage': None,
#       'size': 230,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'htmlacademy-php:master',
#      'ref': 'master',
#      'sha': '02c68fe5cfa0caba874a02494990c2fce85c2edd',
#      'user': {'login': 'htmlacademy-php',
#       'id': 27206120,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3MjA2MTIw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/27206120?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/htmlacademy-php',
#       'html_url': 'https://github.com/htmlacademy-php',
#       'followers_url': 'https://api.github.com/users/htmlacademy-php/followers',
#       'following_url': 'https://api.github.com/users/htmlacademy-php/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/htmlacademy-php/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/htmlacademy-php/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/htmlacademy-php/subscriptions',
#       'organizations_url': 'https://api.github.com/users/htmlacademy-php/orgs',
#       'repos_url': 'https://api.github.com/users/htmlacademy-php/repos',
#       'events_url': 'https://api.github.com/users/htmlacademy-php/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/htmlacademy-php/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 180440600,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODA0NDA2MDA=',
#       'name': '128700-doingsdone-9',
#       'full_name': 'htmlacademy-php/128700-doingsdone-9',
#       'private': False,
#       'owner': {'login': 'htmlacademy-php',
#        'id': 27206120,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3MjA2MTIw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/27206120?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/htmlacademy-php',
#        'html_url': 'https://github.com/htmlacademy-php',
#        'followers_url': 'https://api.github.com/users/htmlacademy-php/followers',
#        'following_url': 'https://api.github.com/users/htmlacademy-php/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/htmlacademy-php/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/htmlacademy-php/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/htmlacademy-php/subscriptions',
#        'organizations_url': 'https://api.github.com/users/htmlacademy-php/orgs',
#        'repos_url': 'https://api.github.com/users/htmlacademy-php/repos',
#        'events_url': 'https://api.github.com/users/htmlacademy-php/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/htmlacademy-php/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/htmlacademy-php/128700-doingsdone-9',
#       'description': 'Юлия Гуткина',
#       'fork': False,
#       'url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9',
#       'forks_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/forks',
#       'keys_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/teams',
#       'hooks_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/hooks',
#       'issue_events_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/events',
#       'assignees_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/tags',
#       'blobs_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/languages',
#       'stargazers_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/stargazers',
#       'contributors_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/contributors',
#       'subscribers_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/subscribers',
#       'subscription_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/subscription',
#       'commits_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/merges',
#       'archive_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/downloads',
#       'issues_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/deployments',
#       'created_at': '2019-04-09T20:02:19Z',
#       'updated_at': '2019-05-13T22:37:32Z',
#       'pushed_at': '2019-05-15T18:40:52Z',
#       'git_url': 'git://github.com/htmlacademy-php/128700-doingsdone-9.git',
#       'ssh_url': 'git@github.com:htmlacademy-php/128700-doingsdone-9.git',
#       'clone_url': 'https://github.com/htmlacademy-php/128700-doingsdone-9.git',
#       'svn_url': 'https://github.com/htmlacademy-php/128700-doingsdone-9',
#       'homepage': 'https://github.com/YuliaGutkina/128700-doingsdone-9',
#       'size': 216,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/13'},
#      'html': {'href': 'https://github.com/htmlacademy-php/128700-doingsdone-9/pull/13'},
#      'issue': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues/13'},
#      'comments': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/issues/13/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/13/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/pulls/13/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/htmlacademy-php/128700-doingsdone-9/statuses/719135dcf088de1771addc7162436b59615fda81'}},
#     'author_association': 'NONE',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'keksobot',
#      'id': 11215289,
#      'node_id': 'MDQ6VXNlcjExMjE1Mjg5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/11215289?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/keksobot',
#      'html_url': 'https://github.com/keksobot',
#      'followers_url': 'https://api.github.com/users/keksobot/followers',
#      'following_url': 'https://api.github.com/users/keksobot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/keksobot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/keksobot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/keksobot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/keksobot/orgs',
#      'repos_url': 'https://api.github.com/users/keksobot/repos',
#      'events_url': 'https://api.github.com/users/keksobot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/keksobot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 5,
#     'maintainer_can_modify': False,
#     'commits': 4,
#     'additions': 193,
#     'deletions': 526,
#     'changed_files': 15}},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z',
#   'org': {'id': 27206120,
#    'login': 'htmlacademy-php',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/htmlacademy-php',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27206120?'}},
#  {'id': '9633454020',
#   'type': 'PushEvent',
#   'actor': {'id': 43792910,
#    'login': 'jbain424',
#    'display_login': 'jbain424',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbain424',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43792910?'},
#   'repo': {'id': 180184957,
#    'name': 'isaink/dashing',
#    'url': 'https://api.github.com/repos/isaink/dashing'},
#   'payload': {'push_id': 3612630709,
#    'size': 6,
#    'distinct_size': 2,
#    'ref': 'refs/heads/jojoProduction',
#    'head': 'fea6d4b160934caefda4aa1089f8acff9e55eee4',
#    'before': '41239b5f0f6750677ff56a102979c3921a8901e1',
#    'commits': [{'sha': '3a374ba649e0804a1655eecdf174e902dec731f9',
#      'author': {'email': '43792910+jbain424@users.noreply.github.com',
#       'name': 'jbain424'},
#      'message': 'Merge pull request #131 from isaink/jojofinalbranch\n\nJojofinalbranch',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/isaink/dashing/commits/3a374ba649e0804a1655eecdf174e902dec731f9'},
#     {'sha': 'bb61ff112bf42d38a1a02fa08e9bfd618621dfe7',
#      'author': {'email': '43792910+jbain424@users.noreply.github.com',
#       'name': 'jbain424'},
#      'message': 'Merge pull request #132 from isaink/jojoProduction\n\nJojo production',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/isaink/dashing/commits/bb61ff112bf42d38a1a02fa08e9bfd618621dfe7'},
#     {'sha': '8cac66ed9d140fcb998b142552c9df57874ccd40',
#      'author': {'email': '43792910+jbain424@users.noreply.github.com',
#       'name': 'jbain424'},
#      'message': 'Merge pull request #133 from isaink/jojoProduction\n\nnewstuff',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/isaink/dashing/commits/8cac66ed9d140fcb998b142552c9df57874ccd40'},
#     {'sha': '70efb033c3900915b1731b9e485e2c3f2b8c7d93',
#      'author': {'email': '39275081+isaink@users.noreply.github.com',
#       'name': 'Isa Alvarado'},
#      'message': 'Merge pull request #134 from isaink/jojoProduction\n\nultimate services CSS',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/isaink/dashing/commits/70efb033c3900915b1731b9e485e2c3f2b8c7d93'},
#     {'sha': '2661512e864f36754c6b75e8635cc2c2f826daec',
#      'author': {'email': 'jonellebain@pursuit.org', 'name': 'jonelle'},
#      'message': 'pushingagain',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isaink/dashing/commits/2661512e864f36754c6b75e8635cc2c2f826daec'},
#     {'sha': 'fea6d4b160934caefda4aa1089f8acff9e55eee4',
#      'author': {'email': 'jonellebain@pursuit.org', 'name': 'jonelle'},
#      'message': 'fixed conflicts',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isaink/dashing/commits/fea6d4b160934caefda4aa1089f8acff9e55eee4'}]},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z'},
#  {'id': '9633454016',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46622658,
#    'name': 'Lombiq/Orchard-JavaScript.Net',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-JavaScript.Net'},
#   'payload': {'push_id': 3612630706,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/BTLR-54',
#    'head': 'c5b6c9b810dc8ab2d5fb74f1528b9a0708292459',
#    'before': 'c5b6c9b810dc8ab2d5fb74f1528b9a0708292459',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '9633454018',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1168206,
#    'login': 'wsalesky',
#    'display_login': 'wsalesky',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wsalesky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1168206?'},
#   'repo': {'id': 78870131,
#    'name': 'srophe/syriac-corpus-app',
#    'url': 'https://api.github.com/repos/srophe/syriac-corpus-app'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/srophe/syriac-corpus-app/issues/230',
#     'repository_url': 'https://api.github.com/repos/srophe/syriac-corpus-app',
#     'labels_url': 'https://api.github.com/repos/srophe/syriac-corpus-app/issues/230/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/srophe/syriac-corpus-app/issues/230/comments',
#     'events_url': 'https://api.github.com/repos/srophe/syriac-corpus-app/issues/230/events',
#     'html_url': 'https://github.com/srophe/syriac-corpus-app/issues/230',
#     'id': 444526434,
#     'node_id': 'MDU6SXNzdWU0NDQ1MjY0MzQ=',
#     'number': 230,
#     'title': 'Slider bar',
#     'user': {'login': 'jedwardwalters',
#      'id': 11543800,
#      'node_id': 'MDQ6VXNlcjExNTQzODAw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/11543800?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jedwardwalters',
#      'html_url': 'https://github.com/jedwardwalters',
#      'followers_url': 'https://api.github.com/users/jedwardwalters/followers',
#      'following_url': 'https://api.github.com/users/jedwardwalters/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jedwardwalters/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jedwardwalters/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jedwardwalters/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jedwardwalters/orgs',
#      'repos_url': 'https://api.github.com/users/jedwardwalters/repos',
#      'events_url': 'https://api.github.com/users/jedwardwalters/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jedwardwalters/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'wsalesky',
#      'id': 1168206,
#      'node_id': 'MDQ6VXNlcjExNjgyMDY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/1168206?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wsalesky',
#      'html_url': 'https://github.com/wsalesky',
#      'followers_url': 'https://api.github.com/users/wsalesky/followers',
#      'following_url': 'https://api.github.com/users/wsalesky/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wsalesky/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wsalesky/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wsalesky/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wsalesky/orgs',
#      'repos_url': 'https://api.github.com/users/wsalesky/repos',
#      'events_url': 'https://api.github.com/users/wsalesky/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wsalesky/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'wsalesky',
#       'id': 1168206,
#       'node_id': 'MDQ6VXNlcjExNjgyMDY=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/1168206?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wsalesky',
#       'html_url': 'https://github.com/wsalesky',
#       'followers_url': 'https://api.github.com/users/wsalesky/followers',
#       'following_url': 'https://api.github.com/users/wsalesky/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wsalesky/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wsalesky/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wsalesky/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wsalesky/orgs',
#       'repos_url': 'https://api.github.com/users/wsalesky/repos',
#       'events_url': 'https://api.github.com/users/wsalesky/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wsalesky/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-05-15T16:12:41Z',
#     'updated_at': '2019-05-15T18:40:52Z',
#     'closed_at': '2019-05-15T18:40:52Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'On the advanced search page, the slider bar is showing up at the bottom:\r\nhttp://wwwb.library.vanderbilt.edu/exist/apps/syriac-corpus/search.html\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/srophe/syriac-corpus-app/issues/comments/492775086',
#     'html_url': 'https://github.com/srophe/syriac-corpus-app/issues/230#issuecomment-492775086',
#     'issue_url': 'https://api.github.com/repos/srophe/syriac-corpus-app/issues/230',
#     'id': 492775086,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDQ5Mjc3NTA4Ng==',
#     'user': {'login': 'wsalesky',
#      'id': 1168206,
#      'node_id': 'MDQ6VXNlcjExNjgyMDY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/1168206?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wsalesky',
#      'html_url': 'https://github.com/wsalesky',
#      'followers_url': 'https://api.github.com/users/wsalesky/followers',
#      'following_url': 'https://api.github.com/users/wsalesky/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wsalesky/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wsalesky/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wsalesky/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wsalesky/orgs',
#      'repos_url': 'https://api.github.com/users/wsalesky/repos',
#      'events_url': 'https://api.github.com/users/wsalesky/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wsalesky/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-05-15T18:40:52Z',
#     'updated_at': '2019-05-15T18:40:52Z',
#     'author_association': 'COLLABORATOR',
#     'body': '@jedwardwalters Fixed! Let me know when you want me to move it to production. '}},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z',
#   'org': {'id': 4365654,
#    'login': 'srophe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/srophe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4365654?'}},
#  {'id': '9633454014',
#   'type': 'WatchEvent',
#   'actor': {'id': 26280459,
#    'login': 'jinwei14',
#    'display_login': 'jinwei14',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jinwei14',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26280459?'},
#   'repo': {'id': 14251284,
#    'name': 'yuce/pyswip',
#    'url': 'https://api.github.com/repos/yuce/pyswip'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z'},
#  {'id': '9633453993',
#   'type': 'IssuesEvent',
#   'actor': {'id': 47398809,
#    'login': 'NolanRogers',
#    'display_login': 'NolanRogers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NolanRogers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47398809?'},
#   'repo': {'id': 144599701,
#    'name': 'zowe/zlux',
#    'url': 'https://api.github.com/repos/zowe/zlux'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/zowe/zlux/issues/150',
#     'repository_url': 'https://api.github.com/repos/zowe/zlux',
#     'labels_url': 'https://api.github.com/repos/zowe/zlux/issues/150/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/zowe/zlux/issues/150/comments',
#     'events_url': 'https://api.github.com/repos/zowe/zlux/issues/150/events',
#     'html_url': 'https://github.com/zowe/zlux/issues/150',
#     'id': 444587407,
#     'node_id': 'MDU6SXNzdWU0NDQ1ODc0MDc=',
#     'number': 150,
#     'title': 'Sanitize input against html script tags',
#     'user': {'login': 'NolanRogers',
#      'id': 47398809,
#      'node_id': 'MDQ6VXNlcjQ3Mzk4ODA5',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/47398809?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NolanRogers',
#      'html_url': 'https://github.com/NolanRogers',
#      'followers_url': 'https://api.github.com/users/NolanRogers/followers',
#      'following_url': 'https://api.github.com/users/NolanRogers/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NolanRogers/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NolanRogers/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NolanRogers/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NolanRogers/orgs',
#      'repos_url': 'https://api.github.com/users/NolanRogers/repos',
#      'events_url': 'https://api.github.com/users/NolanRogers/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NolanRogers/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'jordanfilteau1995',
#      'id': 40768142,
#      'node_id': 'MDQ6VXNlcjQwNzY4MTQy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/40768142?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jordanfilteau1995',
#      'html_url': 'https://github.com/jordanfilteau1995',
#      'followers_url': 'https://api.github.com/users/jordanfilteau1995/followers',
#      'following_url': 'https://api.github.com/users/jordanfilteau1995/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jordanfilteau1995/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jordanfilteau1995/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jordanfilteau1995/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jordanfilteau1995/orgs',
#      'repos_url': 'https://api.github.com/users/jordanfilteau1995/repos',
#      'events_url': 'https://api.github.com/users/jordanfilteau1995/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jordanfilteau1995/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'jordanfilteau1995',
#       'id': 40768142,
#       'node_id': 'MDQ6VXNlcjQwNzY4MTQy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/40768142?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jordanfilteau1995',
#       'html_url': 'https://github.com/jordanfilteau1995',
#       'followers_url': 'https://api.github.com/users/jordanfilteau1995/followers',
#       'following_url': 'https://api.github.com/users/jordanfilteau1995/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jordanfilteau1995/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jordanfilteau1995/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jordanfilteau1995/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jordanfilteau1995/orgs',
#       'repos_url': 'https://api.github.com/users/jordanfilteau1995/repos',
#       'events_url': 'https://api.github.com/users/jordanfilteau1995/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jordanfilteau1995/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/zowe/zlux/milestones/16',
#      'html_url': 'https://github.com/zowe/zlux/milestone/16',
#      'labels_url': 'https://api.github.com/repos/zowe/zlux/milestones/16/labels',
#      'id': 4287570,
#      'node_id': 'MDk6TWlsZXN0b25lNDI4NzU3MA==',
#      'number': 16,
#      'title': '1.3.0',
#      'description': 'Zowe 1.3.0 Release . Previous release was 1.2.0',
#      'creator': {'login': 'NolanRogers',
#       'id': 47398809,
#       'node_id': 'MDQ6VXNlcjQ3Mzk4ODA5',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/47398809?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/NolanRogers',
#       'html_url': 'https://github.com/NolanRogers',
#       'followers_url': 'https://api.github.com/users/NolanRogers/followers',
#       'following_url': 'https://api.github.com/users/NolanRogers/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/NolanRogers/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/NolanRogers/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/NolanRogers/subscriptions',
#       'organizations_url': 'https://api.github.com/users/NolanRogers/orgs',
#       'repos_url': 'https://api.github.com/users/NolanRogers/repos',
#       'events_url': 'https://api.github.com/users/NolanRogers/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/NolanRogers/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 12,
#      'closed_issues': 3,
#      'state': 'open',
#      'created_at': '2019-05-06T13:07:04Z',
#      'updated_at': '2019-05-15T18:40:52Z',
#      'due_on': '2019-05-24T07:00:00Z',
#      'closed_at': None},
#     'comments': 0,
#     'created_at': '2019-05-15T18:40:52Z',
#     'updated_at': '2019-05-15T18:40:52Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Acceptance Criteria:\n\nIf user inputs <script></script> tag in some input box, the output gets sanitized and is not executed.'}},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z',
#   'org': {'id': 41340454,
#    'login': 'zowe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zowe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41340454?'}},
#  {'id': '9633453981',
#   'type': 'PushEvent',
#   'actor': {'id': 23697,
#    'login': 'lutter',
#    'display_login': 'lutter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lutter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23697?'},
#   'repo': {'id': 130174051,
#    'name': 'graphprotocol/graph-node',
#    'url': 'https://api.github.com/repos/graphprotocol/graph-node'},
#   'payload': {'push_id': 3612630696,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': 'e604f3c875727529ae76f4371adc91cc8d841a74',
#    'before': 'f7cee40ae0363a4541c8d6e9a22d929dffe6a709',
#    'commits': [{'sha': 'e604f3c875727529ae76f4371adc91cc8d841a74',
#      'author': {'email': 'lutter@watzmann.net', 'name': 'David Lutterkort'},
#      'message': 'store/postgres: Add an index on event_meta_data(source)\n\nWe find event_meta_data during block reversions by the source attribute,\nand not having an index on it slows down those queries, and therefore block\nreversion, dramatically. In one case, query time for a block reversion goes\nfrom 18s to 5ms after adding the index.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/graphprotocol/graph-node/commits/e604f3c875727529ae76f4371adc91cc8d841a74'}]},
#   'public': True,
#   'created_at': '2019-05-15T18:40:52Z',
#   'org': {'id': 38020273,
#    'login': 'graphprotocol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/graphprotocol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38020273?'}},
#  {'id': '9633453986',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 20340533,
#    'login': 'rkeverman',
#    'display_login': 'rkeverman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rkeverman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20340533?'},
#   'repo': {'id': 98563786,
#    'name': 'p4lang/p4lang.github.io',
#    'url': 'https://api.github.com/repos/p4lang/p4lang.github.io'},
#   'payload': {'action': 'closed',
#    'number': 405,
#    'pull_request': {'url': 'https://api.github.com/repos/p4lang/p4lang.github.io/pulls/405',
#     'id': 279217078,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc5MjE3MDc4',
# ...
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 141753419,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDE3NTM0MTk=',
#       'name': 'aws-toolkit-vscode',
#       'full_name': 'aws/aws-toolkit-vscode',
#       'private': False,
#       'owner': {'login': 'aws',
#        'id': 2232217,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMzIyMTc=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/2232217?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/aws',
#        'html_url': 'https://github.com/aws',
#        'followers_url': 'https://api.github.com/users/aws/followers',
#        'following_url': 'https://api.github.com/users/aws/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/aws/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/aws/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/aws/subscriptions',
#        'organizations_url': 'https://api.github.com/users/aws/orgs',
#        'repos_url': 'https://api.github.com/users/aws/repos',
#        'events_url': 'https://api.github.com/users/aws/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/aws/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/aws/aws-toolkit-vscode',
#       'description': 'AWS Toolkit for Visual Studio Code, an extension for working with AWS services including AWS Lambda.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/aws/aws-toolkit-vscode',
#       'forks_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/forks',
#       'keys_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/teams',
#       'hooks_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/hooks',
#       'issue_events_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/events',
#       'assignees_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/tags',
#       'blobs_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/languages',
#       'stargazers_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/stargazers',
#       'contributors_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/contributors',
#       'subscribers_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/subscribers',
#       'subscription_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/subscription',
#       'commits_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/merges',
#       'archive_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/downloads',
#       'issues_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/deployments',
#       'created_at': '2018-07-20T20:09:29Z',
#       'updated_at': '2019-05-15T15:15:45Z',
#       'pushed_at': '2019-05-15T01:09:40Z',
#       'git_url': 'git://github.com/aws/aws-toolkit-vscode.git',
#       'ssh_url': 'git@github.com:aws/aws-toolkit-vscode.git',
#       'clone_url': 'https://github.com/aws/aws-toolkit-vscode.git',
#       'svn_url': 'https://github.com/aws/aws-toolkit-vscode',
#       'homepage': None,
#       'size': 4522,
#       'stargazers_count': 556,
#       'watchers_count': 556,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 34,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 134,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 34,
#       'open_issues': 134,
#       'watchers': 556,
#       'default_branch': 'develop'}},
#     'base': {'label': 'aws:develop',
#      'ref': 'develop',
#      'sha': '0e6954d4bcd3e9df9f67c51b5f46034c5050048a',
#      'user': {'login': 'aws',
#       'id': 2232217,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMzIyMTc=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/2232217?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aws',
#       'html_url': 'https://github.com/aws',
#       'followers_url': 'https://api.github.com/users/aws/followers',
#       'following_url': 'https://api.github.com/users/aws/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aws/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aws/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aws/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aws/orgs',
#       'repos_url': 'https://api.github.com/users/aws/repos',
#       'events_url': 'https://api.github.com/users/aws/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aws/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 141753419,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDE3NTM0MTk=',
#       'name': 'aws-toolkit-vscode',
#       'full_name': 'aws/aws-toolkit-vscode',
#       'private': False,
#       'owner': {'login': 'aws',
#        'id': 2232217,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMzIyMTc=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/2232217?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/aws',
#        'html_url': 'https://github.com/aws',
#        'followers_url': 'https://api.github.com/users/aws/followers',
#        'following_url': 'https://api.github.com/users/aws/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/aws/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/aws/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/aws/subscriptions',
#        'organizations_url': 'https://api.github.com/users/aws/orgs',
#        'repos_url': 'https://api.github.com/users/aws/repos',
#        'events_url': 'https://api.github.com/users/aws/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/aws/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/aws/aws-toolkit-vscode',
#       'description': 'AWS Toolkit for Visual Studio Code, an extension for working with AWS services including AWS Lambda.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/aws/aws-toolkit-vscode',
#       'forks_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/forks',
#       'keys_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/teams',
#       'hooks_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/hooks',
#       'issue_events_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/events',
#       'assignees_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/tags',
#       'blobs_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/languages',
#       'stargazers_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/stargazers',
#       'contributors_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/contributors',
#       'subscribers_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/subscribers',
#       'subscription_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/subscription',
#       'commits_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/merges',
#       'archive_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/downloads',
#       'issues_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/aws/aws-toolkit-vscode/deployments',
#       'created_at': '2018-07-20T20:09:29Z',
#       'updated_at': '2019-05-15T15:15:45Z',
#       'pushed_at': '2019-05-15T01:09:40Z',
#       'git_url': 'git://github.com/aws/aws-toolkit-vscode.git',
#       'ssh_url': 'git@github.com:aws/aws-toolkit-vscode.git',
#       'clone_url': 'https://github.com/aws/aws-toolkit-vscode.git',
#       'svn_url': 'https://github.com/aws/aws-toolkit-vscode',
#       'homepage': None,
#       'size': 4522,
#       'stargazers_count': 556,
#       'watchers_count': 556,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 34,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 134,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 34,
#       'open_issues': 134,
#       'watchers': 556,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/pulls/555'},
#      'html': {'href': 'https://github.com/aws/aws-toolkit-vscode/pull/555'},
#      'issue': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues/555'},
#      'comments': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/issues/555/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/pulls/555/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/pulls/555/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/aws/aws-toolkit-vscode/statuses/ae87cc72affb81bb70c7c2ef6b102cd2f26ee9d0'}},
#     'author_association': 'CONTRIBUTOR'}},
#   'public': True,
#   'created_at': '2019-05-15T18:40:51Z',
#   'org': {'id': 2232217,
#    'login': 'aws',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aws',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?'}},
#  {'id': '9633453898',
#   'type': 'PushEvent',
#   'actor': {'id': 17193977,
#    'login': 'newstools',
#    'display_login': 'newstools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newstools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#   'repo': {'id': 184161501,
#    'name': 'newstools/2019-all-africa',
#    'url': 'https://api.github.com/repos/newstools/2019-all-africa'},
#   'payload': {'push_id': 3612630645,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f77e3130d432cb0e6044d55f705a241f739fc994',
#    'before': 'acebe94d332e26aea099803800ca034acb64adf8',
#    'commits': [{'sha': 'f77e3130d432cb0e6044d55f705a241f739fc994',
#      'author': {'email': 'github@newstools.co.za', 'name': 'NewsTools'},
#      'message': 'Created Text For URL [allafrica.com/stories/201905150476.html]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newstools/2019-all-africa/commits/f77e3130d432cb0e6044d55f705a241f739fc994'}]},
#   'public': True,
#   'created_at': '2019-05-15T18:40:51Z'},
#  {'id': '9633453900',
#   'type': 'CreateEvent',
#   'actor': {'id': 23040076,
#    'login': 'greenkeeper[bot]',
#    'display_login': 'greenkeeper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greenkeeper[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23040076?'},
#   'repo': {'id': 133892998,
#    'name': 'Leko/zapshot',
#    'url': 'https://api.github.com/repos/Leko/zapshot'},
#   'payload': {'ref': 'greenkeeper/eslint-plugin-flowtype-3.9.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': ':zap: JavaScript benchmarking tool to help continuous performance optimization',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-15T18:40:51Z'}]

# %% [markdown]
# ### Checking out the status of your request

# %%
#get the status of your post request
r.status_code
# Out:
# 200

# %% [markdown]
# #### Types of status codes
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)

# %% [markdown]
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %% [markdown]
# https://http.cat

# %%
#get status code for a "broken" link

r = requests.get('https://api.github.com/fake-ending')
r.status_code
# Out:
# 403

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
r.json()
# Out:
# {'message': "API rate limit exceeded for 65.207.79.74. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)",
#  'documentation_url': 'https://developer.github.com/v3/#rate-limiting'}

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection.
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception.
# - A Timeout exception will be raised if a request times out.
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# Now that we know a bit more about APIs and how to interact with them in python, let's actually investigate an API from scratch.
#
# To start, go over to the API documentation at:
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
#
# <img src="311_api_docs.png">

# %% [markdown]
# ## Make an initial API call to retrieve 311 complaints from a neighborhood or zip code of your choice in New York City.

# %% [markdown]
# ### Using Requests

# %%
import requests
import pandas as pd

zip_code = '11004'

# can't figure out date ranges at the moment...
start_date = '2018-01-01T12:00:00'
end_date = '2018-02-01T12:00:00'

# create pull request based on parameters
# https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9 click API

url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json?incident_zip={}".format(zip_code)

# do the pull
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
else:
    print('Hit an error.')

# %% [markdown]
# ## Briefly Explore the Structure of the Response You Received.

# %% [markdown]
# ### Let's look at the output of our API call to NYC 311

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
len(data)
# Out:
# 1000

# %%
data[16]['complaint_type']
# Out:
# 'Sewer'

# %% [markdown]
# ### Libraries for company-specific APIs
#
# Google has its own libraries you can import to access their apis. <br>
# NYC also uses the `sodapy` library, Socrata, to manage their open data.

# %% [markdown]
# #### Extra credit for later if you want to play with it

# %%
# Install before running 
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading https://files.pythonhosted.org/packages/11/02/5baf6e10a47018babcc43e3ed03a6f13712187f4ab1fbe263b479c77d117/sodapy-1.5.2-py2.py3-none-any.whl
# Requirement already satisfied: future>=0.17.1 in /anaconda3/lib/python3.7/site-packages (from sodapy) (0.17.1)
# Requirement already satisfied: requests>=2.20.0 in /anaconda3/lib/python3.7/site-packages (from sodapy) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2019.3.9)
# Installing collected packages: sodapy
# Successfully installed sodapy-1.5.2

# %% [markdown]
# #### Tokenize yourself, B!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! This is instantaneous and simple. No credit cards required!

# %%
token = '' 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
type(results)
# Out:
# list

# %%
len(results)
# Out:
# 1000

# %%
results[0]
# Out:
# {'address_type': 'ADDRESS',
#  'agency': 'NYPD',
#  'agency_name': 'New York City Police Department',
#  'bbl': '4084460001',
#  'borough': 'QUEENS',
#  'city': 'GLEN OAKS',
#  'closed_date': '2019-05-14T00:45:22.000',
#  'community_board': '13 QUEENS',
#  'complaint_type': 'Noise - Residential',
#  'created_date': '2019-05-13T23:06:30.000',
#  'cross_street_1': '73 AVENUE',
#  'cross_street_2': 'BEND',
#  'descriptor': 'Banging/Pounding',
#  'due_date': '2019-05-14T07:06:30.000',
#  'facility_type': 'Precinct',
#  'incident_address': '73-01 260 STREET',
#  'incident_zip': '11004',
#  'latitude': '40.75076013157645',
#  'location': {'type': 'Point',
#   'coordinates': [-73.717529079357, 40.750760131576]},
#  'location_type': 'Residential Building/House',
#  'longitude': '-73.7175290793568',
#  'open_data_channel_type': 'ONLINE',
#  'park_borough': 'QUEENS',
#  'park_facility_name': 'Unspecified',
#  'resolution_action_updated_date': '2019-05-14T00:45:22.000',
#  'resolution_description': 'The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.',
#  'status': 'Closed',
#  'street_name': '260 STREET',
#  'unique_key': '42663284',
#  'x_coordinate_state_plane': '1062514',
#  'y_coordinate_state_plane': '212925'}

# %%
df_1 = pd.DataFrame(results)

print(len(df_1))
print(df_1.columns)
df_1.head()
# Out:
# 1000
# Index(['address_type', 'agency', 'agency_name', 'bbl', 'borough', 'city',
#        'closed_date', 'community_board', 'complaint_type', 'created_date',
#        'cross_street_1', 'cross_street_2', 'descriptor', 'due_date',
#        'facility_type', 'incident_address', 'incident_zip',
#        'intersection_street_1', 'intersection_street_2', 'latitude',
#        'location', 'location_type', 'longitude', 'open_data_channel_type',
#        'park_borough', 'park_facility_name', 'resolution_action_updated_date',
#        'resolution_description', 'status', 'street_name',
#        'taxi_pick_up_location', 'unique_key', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane'],
#       dtype='object')
#    address_type agency                             agency_name         bbl  \
# 0       ADDRESS   NYPD         New York City Police Department  4084460001
# 1     BLOCKFACE    DOT            Department of Transportation         NaN
# 2       ADDRESS    DEP  Department of Environmental Protection  4084430237
# 3  INTERSECTION    DEP  Department of Environmental Protection         NaN
# 4       ADDRESS    DOT            Department of Transportation  4084420001
#
#   borough       city              closed_date community_board  \
# 0  QUEENS  GLEN OAKS  2019-05-14T00:45:22.000       13 QUEENS
# 1  QUEENS  Glen Oaks                      NaN       13 QUEENS
# 2  QUEENS  Glen Oaks                      NaN       13 QUEENS
# 3  QUEENS  Glen Oaks                      NaN       13 QUEENS
# 4  QUEENS  GLEN OAKS                      NaN       13 QUEENS
#
#         complaint_type             created_date  ... park_borough  \
# 0  Noise - Residential  2019-05-13T23:06:30.000  ...       QUEENS
# 1     Street Condition  2019-05-13T11:39:14.000  ...       QUEENS
# 2                Sewer  2019-05-13T20:50:00.000  ...       QUEENS
# 3                Sewer  2019-05-13T16:50:00.000  ...       QUEENS
# 4     Street Condition  2019-05-13T11:43:22.000  ...       QUEENS
#
#   park_facility_name resolution_action_updated_date  \
# 0        Unspecified        2019-05-14T00:45:22.000
# 1        Unspecified        2019-05-13T11:39:14.000
# 2        Unspecified                            NaN
# 3        Unspecified                            NaN
# 4        Unspecified                            NaN
#
#                               resolution_description  status  \
# 0  The Police Department responded to the complai...  Closed
# 1  The Department of Transportation referred this...    Open
# 2                                                NaN    Open
# 3                                                NaN    Open
# 4  The Department of Transportation requires 10 d...    Open
#
#            street_name taxi_pick_up_location unique_key  \
# 0           260 STREET                   NaN   42663284
# 1            73 AVENUE                   NaN   42663518
# 2  LITTLE NECK PARKWAY                   NaN   42662708
# 3                  NaN                   NaN   42660564
# 4  LITTLE NECK PARKWAY                   NaN   42660605
#
#   x_coordinate_state_plane y_coordinate_state_plane
# 0                  1062514                   212925
# 1                  1062558                   213091
# 2                  1061214                   213791
# 3                  1064245                   210023
# 4                  1061834                   212496
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Create a Pandas DataFrame of the Data From the Response

# %%
df_2 = pd.DataFrame(data)

print(len(df_2))
print(df_2.columns)
df_2.head()
# Out:
# 1000
# Index(['address_type', 'agency', 'agency_name', 'bbl', 'borough', 'city',
#        'closed_date', 'community_board', 'complaint_type', 'created_date',
#        'cross_street_1', 'cross_street_2', 'descriptor', 'due_date',
#        'facility_type', 'incident_address', 'incident_zip',
#        'intersection_street_1', 'intersection_street_2', 'latitude',
#        'location', 'location_type', 'longitude', 'open_data_channel_type',
#        'park_borough', 'park_facility_name', 'resolution_action_updated_date',
#        'resolution_description', 'status', 'street_name',
#        'taxi_pick_up_location', 'unique_key', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane'],
#       dtype='object')
#    address_type agency                             agency_name         bbl  \
# 0       ADDRESS   NYPD         New York City Police Department  4084460001
# 1     BLOCKFACE    DOT            Department of Transportation         NaN
# 2       ADDRESS    DEP  Department of Environmental Protection  4084430237
# 3  INTERSECTION    DEP  Department of Environmental Protection         NaN
# 4       ADDRESS    DOT            Department of Transportation  4084420001
#
#   borough       city              closed_date community_board  \
# 0  QUEENS  GLEN OAKS  2019-05-14T00:45:22.000       13 QUEENS
# 1  QUEENS  Glen Oaks                      NaN       13 QUEENS
# 2  QUEENS  Glen Oaks                      NaN       13 QUEENS
# 3  QUEENS  Glen Oaks                      NaN       13 QUEENS
# 4  QUEENS  GLEN OAKS                      NaN       13 QUEENS
#
#         complaint_type             created_date  ... park_borough  \
# 0  Noise - Residential  2019-05-13T23:06:30.000  ...       QUEENS
# 1     Street Condition  2019-05-13T11:39:14.000  ...       QUEENS
# 2                Sewer  2019-05-13T20:50:00.000  ...       QUEENS
# 3                Sewer  2019-05-13T16:50:00.000  ...       QUEENS
# 4     Street Condition  2019-05-13T11:43:22.000  ...       QUEENS
#
#   park_facility_name resolution_action_updated_date  \
# 0        Unspecified        2019-05-14T00:45:22.000
# 1        Unspecified        2019-05-13T11:39:14.000
# 2        Unspecified                            NaN
# 3        Unspecified                            NaN
# 4        Unspecified                            NaN
#
#                               resolution_description  status  \
# 0  The Police Department responded to the complai...  Closed
# 1  The Department of Transportation referred this...    Open
# 2                                                NaN    Open
# 3                                                NaN    Open
# 4  The Department of Transportation requires 10 d...    Open
#
#            street_name taxi_pick_up_location unique_key  \
# 0           260 STREET                   NaN   42663284
# 1            73 AVENUE                   NaN   42663518
# 2  LITTLE NECK PARKWAY                   NaN   42662708
# 3                  NaN                   NaN   42660564
# 4  LITTLE NECK PARKWAY                   NaN   42660605
#
#   x_coordinate_state_plane y_coordinate_state_plane
# 0                  1062514                   212925
# 1                  1062558                   213091
# 2                  1061214                   213791
# 3                  1064245                   210023
# 4                  1061834                   212496
#
# [5 rows x 34 columns]

# %%
df_2.complaint_type.unique()
# Out:
# array(['Noise - Residential', 'Street Condition', 'Sewer',
#        'General Construction/Plumbing', 'DOF Property - Reduction Issue',
#        'Other Enforcement', 'Street Light Condition', 'Traffic',
#        'Construction Safety Enforcement', 'New Tree Request',
#        'Damaged Tree', 'Dead/Dying Tree', 'Root/Sewer/Sidewalk Condition',
#        'Request Large Bulky Item Collection', 'Water System',
#        'Sidewalk Condition', 'Plumbing', 'Taxi Complaint',
#        'Dirty Conditions', 'Noise - Park', 'Standing Water',
#        'Missed Collection (All Materials)', 'Sanitation Condition',
#        'Building/Use', 'DOF Property - Payment Issue', 'Unleashed Dog',
#        'Traffic Signal Condition', 'Overgrown Tree/Branches',
#        'Noise - Commercial', 'Illegal Parking', 'Graffiti',
#        'Blocked Driveway', 'Litter Basket / Request', 'Derelict Vehicle',
#        'DOF Property - Request Copy', 'Housing - Low Income Senior',
#        'OUTSIDE BUILDING', 'Noise - Street/Sidewalk',
#        'Emergency Response Team (ERT)', 'Water Conservation',
#        'Industrial Waste', 'Noise', 'UNSANITARY CONDITION',
#        'PAINT/PLASTER', 'ELECTRIC', 'Curb Condition',
#        'For Hire Vehicle Complaint', 'BEST/Site Safety',
#        'DOF Property - Update Account', 'Drug Activity', 'Air Quality',
#        'Asbestos', 'Lead', 'Sustainability Enforcement',
#        'Miscellaneous Categories',
#        'Special Projects Inspection Team (SPIT)',
#        'Building Marshals office', 'Borough Office',
#        'Executive Inspections', 'Quality of Life', 'Facades',
#        'Food Establishment', 'Disorderly Youth',
#        'Investigations and Discipline (IAD)', 'Electrical', 'Rodent',
#        'Food Poisoning', 'Animal in a Park', 'Consumer Complaint',
#        'DOF Property - Owner Issue', 'Street Sign - Missing',
#        'Street Sign - Damaged', 'Non-Residential Heat',
#        'Street Sign - Dangling', 'Unsanitary Pigeon Condition',
#        'Vacant Lot', 'Maintenance or Facility', 'SCRIE',
#        'Taxpayer Advocate Inquiry', 'Housing Options'], dtype=object)

# %% [markdown]
# ## Create a Histogram of the Complaint Types From Your Dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_2.complaint_type.value_counts().plot(kind='barh', figsize=(8,12))

# %% [markdown]
# ## If we have time:
#
# https://github.com/toddmotto/public-apis
#
#
# find a buddy, find a free api, get the key, and do a get. Try to transform the response into a df.

# %%
df_2.complaint_type.value_counts().plot(kind='barh')

# %%
pip install openbrewerydb
# Out:
# Collecting openbrewerydb
#   Downloading https://files.pythonhosted.org/packages/c7/c9/860c74424968ba572114a59a6b49dbfdb8ad18b24f176a0f398e3d590d75/openbrewerydb-0.1.1-py2.py3-none-any.whl
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from openbrewerydb) (2.21.0)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.7/site-packages (from openbrewerydb) (0.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->openbrewerydb) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->openbrewerydb) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->openbrewerydb) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->openbrewerydb) (3.0.4)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas->openbrewerydb) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /anaconda3/lib/python3.7/site-packages (from pandas->openbrewerydb) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas->openbrewerydb) (2.8.0)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->openbrewerydb) (1.12.0)
# Installing collected packages: openbrewerydb
# Successfully installed openbrewerydb-0.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://api.openbrewerydb.org/breweries'
r2 = requests.get(url)

# %%
data = r2.json()

# %%
pd.DataFrame(data)
# Out:
#    brewery_type               city        country   id          latitude  \
# 0         micro         Birmingham  United States    2         33.524521
# 1         micro         Tuscaloosa  United States    4  33.1984907123707
# 2         micro         Birmingham  United States   44  33.5128492349817
# 3         micro         Huntsville  United States   46        34.7277523
# 4         micro            Wasilla  United States   55        61.5752695
# 5         micro          Anchorage  United States   76  61.1384893547315
# 6         micro             Tucson  United States   94  32.2467372722906
# 7      contract         Scottsdale  United States   98  33.4972615652174
# 8       brewpub           Chandler  United States  104        33.3053455
# 9         micro             Tucson  United States  107   32.201608314954
# 10        micro             Tucson  United States  127  32.2504946147872
# 11        micro           Williams  United States  141        35.2500282
# 12        micro   Lake Havasu City  United States  163  34.4689736300844
# 13        micro             Peoria  United States  182  33.6687744976834
# 14     regional           Chandler  United States  187        33.3032436
# 15      brewpub           Surprise  United States  198       33.63822125
# 16        micro            Phoenix  United States  219         33.516633
# 17      brewpub          Paragould  United States  225  36.0316358142169
# 18        micro  North Little Rock  United States  235  34.7594277548278
# 19        micro        Little Rock  United States  247         34.742845
#
#             longitude                                         name  \
# 0          -86.774322                          Avondale Brewing Co
# 1   -87.5621551272424             Band of Brothers Brewing Company
# 2   -86.7914000624146                             Trim Tab Brewing
# 3         -86.5932014                         Yellowhammer Brewery
# 4        -149.4127103                     Bearpaw River Brewing Co
# 5   -149.879076042937                       King Street Brewing Co
# 6   -110.992750525872                                 1912 Brewing
# 7   -111.924474347826                            Bad Water Brewing
# 8         -111.911126          BJs Restaurant & Brewery - Chandler
# 9   -110.821778571134                            BlackRock Brewers
# 10  -111.005452051979                           Dragoon Brewing Co
# 11       -112.1892168                 Grand Canyon Brewing Company
# 12  -114.342433477881                          Mudshark Brewing Co
# 13  -112.238054093359                             Richter Aleworks
# 14       -111.8423459                            SanTan Brewing Co
# 15  -112.357813820157                             State 48 Brewery
# 16       -112.0301125                   Wren House Brewing Company
# 17  -90.5204797204622  Brick Oven Pizza Co / Brick & Forge Brewing
# 18  -92.2726892120821                      Diamond Bear Brewing Co
# 19         -92.260019                           Lost Forty Brewing
#
#          phone postal_code     state                             street  \
# 0   2057775456  35222-1932   Alabama                      201 41st St S
# 1   2052665137  35401-4653   Alabama                      1605 23rd Ave
# 2   2057030536  35233-3401   Alabama                     2721 5th Ave S
# 3   2569755950  35805-3046   Alabama                 2600 Clinton Ave W
# 4               99654-7679    Alaska          4605 E Palmer Wasilla Hwy
# 5   9073365464       99515    Alaska                   9050 King Street
# 6   5202564851  85745-1444   Arizona         2045 N Forbes Blvd Ste 105
# 7   5207459175  85251-3914   Arizona                   4216 N Brown Ave
# 8   4809170631  85226-5175   Arizona               3155 W Chandler Blvd
# 9   5202073203  85710-6767   Arizona       1664 S Research Loop Ste 200
# 10  5203293606  85745-1214   Arizona            1859 W Grant Rd Ste 111
# 11  8005132072  86046-2530   Arizona                     233 W Route 66
# 12  9284532981  86403-0966   Arizona                    210 Swanson Ave
# 13  6029086553  85382-7434   Arizona  8279 W Lake Pleasant Pkwy Ste 110
# 14  4809178700  85225-7862   Arizona                  8 S San Marcos Pl
# 15  6235841095  85374-3873   Arizona                    13823 W Bell Rd
# 16  6022449184  85008-2713   Arizona                     2125 N 24th St
# 17  8702364200  72450-6122  Arkansas                    2410 Linwood Dr
# 18  5017082739  72114-5381  Arkansas                  600 N Broadway St
# 19  5013197275       72202  Arkansas                        501 Byrd St
#
#    tag_list                updated_at                           website_url
# 0        []  2018-08-23T23:19:57.825Z        http://www.avondalebrewing.com
# 1        []  2018-08-23T23:19:59.462Z      http://www.bandofbrosbrewing.com
# 2        []  2018-08-23T23:20:31.423Z         http://www.trimtabbrewing.com
# 3        []  2018-08-23T23:20:33.102Z    http://www.yellowhammerbrewery.com
# 4        []  2018-08-23T23:20:40.743Z        http://bearpawriverbrewing.com
# 5        []  2018-08-23T23:20:57.179Z      http://www.kingstreetbrewing.com
# 6        []  2018-08-23T23:21:11.302Z            http://www.1912brewing.com
# 7        []  2018-08-23T23:21:15.169Z        http://www.badwaterbrewing.com
# 8        []  2018-08-23T23:21:21.165Z         http://www.bjsrestaurants.com
# 9        []  2018-08-23T23:21:23.794Z                   http://www.brb.beer
# 10       []  2018-08-23T23:21:40.563Z         http://www.dragoonbrewing.com
# 11       []  2018-08-23T23:21:53.397Z   http://www.grandcanyonbrewingco.com
# 12       []  2018-08-23T23:22:12.542Z      http://www.mudsharkbrewingco.com
# 13       []  2018-08-23T23:22:29.385Z        http://www.richteraleworks.com
# 14       []  2018-08-23T23:22:33.482Z          http://www.santanbrewing.com
# 15       []  2018-08-23T23:22:41.468Z
# 16       []  2018-08-23T23:22:59.255Z       http://www.wrenhousebrewing.com
# 17       []  2018-08-23T23:23:05.438Z  http://www.brickovenpizzacompany.com
# 18       []  2018-08-23T23:23:14.931Z            http://www.diamondbear.com
# 19       []  2018-08-23T23:23:24.018Z         http://www.lost40brewing.com/

# %%
url2 = 'http://jservice.io/api/clues'
r3 = requests.get(url2)

# %%
r3.status_code
# Out:
# 200

# %%
data = r3.json()

# %%
df3 = pd.DataFrame(data)

# %%
df3
# Out:
#                      airdate                                   answer  \
# 0   1985-02-08T12:00:00.000Z                     the Western division
# 1   1985-02-08T12:00:00.000Z      sold flowers (flower girl accepted)
# 2   1985-02-08T12:00:00.000Z                     <i>Star Trek III</i>
# 3   1985-02-08T12:00:00.000Z                  (1 of) kangaroo and emu
# 4   1985-02-08T12:00:00.000Z                               cat people
# 5   1985-02-08T12:00:00.000Z                                    Maine
# 6   1985-02-08T12:00:00.000Z                                 a midget
# 7   1985-02-08T12:00:00.000Z                                wranglers
# 8   1985-02-08T12:00:00.000Z                    <i>Risky Business</i>
# 9   1985-02-08T12:00:00.000Z                       "Waltzing Matilda"
# 10  1985-02-08T12:00:00.000Z                               a catapult
# 11  1985-02-08T12:00:00.000Z                           a whistle stop
# 12  1985-02-08T12:00:00.000Z                               Don Larsen
# 13  1985-02-08T12:00:00.000Z                                a bailiff
# 14  1985-02-08T12:00:00.000Z                         <i>All of Me</i>
# 15  1985-02-08T12:00:00.000Z                          Tasmanian devil
# 16  1985-02-08T12:00:00.000Z                               a catalyst
# 17  1985-02-08T12:00:00.000Z                            the Democrats
# 18  1985-02-08T12:00:00.000Z                              Fenway Park
# 19  1985-02-08T12:00:00.000Z               cartoonists (or animators)
# 20  1985-02-08T12:00:00.000Z                           <i>Amadeus</i>
# 21  1985-02-08T12:00:00.000Z                           Maggie the Cat
# 22  1985-02-08T12:00:00.000Z                          Harry S. Truman
# 23  1985-02-08T12:00:00.000Z                          Sparky Anderson
# 24  1985-02-08T12:00:00.000Z                          Sparky Anderson
# 25  1985-02-08T12:00:00.000Z                               a CAT scan
# 26  1984-12-14T12:00:00.000Z                                Anchorage
# 27  1984-12-14T12:00:00.000Z                                   quartz
# 28  1984-12-14T12:00:00.000Z                               maitre d\'
# 29  1984-12-14T12:00:00.000Z                                  Rebecca
# ..                       ...                                      ...
# 70  1984-12-12T12:00:00.000Z                             a paper clip
# 71  1984-12-12T12:00:00.000Z                           the Bronze Age
# 72  1984-12-12T12:00:00.000Z  Natalie Wood, James Dean, and Sal Mineo
# 73  1984-12-12T12:00:00.000Z                     Bavarian Motor Works
# 74  1984-12-12T12:00:00.000Z                                  Arizona
# 75  1984-12-12T12:00:00.000Z                          hard of hearing
# 76  1984-12-12T12:00:00.000Z                               Archimedes
# 77  1984-12-12T12:00:00.000Z                                 painting
# 78  1984-12-12T12:00:00.000Z                         Elizabeth Taylor
# 79  1984-12-12T12:00:00.000Z                                  Vermont
# 80  1984-12-12T12:00:00.000Z                               Hardcastle
# 81  1984-12-12T12:00:00.000Z                              a submarine
# 82  1984-12-12T12:00:00.000Z                          the Phoenicians
# 83  1984-12-12T12:00:00.000Z                               John Wayne
# 84  1984-12-12T12:00:00.000Z                               John Wayne
# 85  1984-12-12T12:00:00.000Z                           South Carolina
# 86  1984-12-12T12:00:00.000Z               <i>A Hard Day\'s Night</i>
# 87  1984-12-11T12:00:00.000Z                            Richard Pryor
# 88  1984-12-11T12:00:00.000Z                                    a fox
# 89  1984-12-11T12:00:00.000Z                                    a fox
# 90  1984-12-11T12:00:00.000Z                           Victoria Cross
# 91  1984-12-11T12:00:00.000Z                                     pool
# 92  1984-12-11T12:00:00.000Z                               the Sphinx
# 93  1984-12-11T12:00:00.000Z                               Jack Benny
# 94  1984-12-11T12:00:00.000Z                                  a camel
# 95  1984-12-11T12:00:00.000Z                                  a camel
# 96  1984-12-11T12:00:00.000Z                         the Purple Heart
# 97  1984-12-11T12:00:00.000Z                   <i>Dr. Strangelove</i>
# 98  1984-12-11T12:00:00.000Z                             William Penn
# 99  1984-12-11T12:00:00.000Z                    the Smothers Brothers
#
#                                              category  category_id  \
# 0   {'id': 2, 'title': 'baseball', 'created_at': '...            2
# 1   {'id': 3, 'title': 'odd jobs', 'created_at': '...            3
# 2   {'id': 4, 'title': 'movies', 'created_at': '20...            4
# 3   {'id': 5, 'title': 'australia', 'created_at': ...            5
# 4   {'id': 6, 'title': '"cat" egory', 'created_at'...            6
# 5   {'id': 1, 'title': 'politics', 'created_at': '...            1
# 6   {'id': 2, 'title': 'baseball', 'created_at': '...            2
# 7   {'id': 3, 'title': 'odd jobs', 'created_at': '...            3
# 8   {'id': 4, 'title': 'movies', 'created_at': '20...            4
# 9   {'id': 5, 'title': 'australia', 'created_at': ...            5
# 10  {'id': 6, 'title': '"cat" egory', 'created_at'...            6
# 11  {'id': 1, 'title': 'politics', 'created_at': '...            1
# 12  {'id': 2, 'title': 'baseball', 'created_at': '...            2
# 13  {'id': 3, 'title': 'odd jobs', 'created_at': '...            3
# 14  {'id': 4, 'title': 'movies', 'created_at': '20...            4
# 15  {'id': 5, 'title': 'australia', 'created_at': ...            5
# 16  {'id': 6, 'title': '"cat" egory', 'created_at'...            6
# 17  {'id': 1, 'title': 'politics', 'created_at': '...            1
# 18  {'id': 2, 'title': 'baseball', 'created_at': '...            2
# 19  {'id': 3, 'title': 'odd jobs', 'created_at': '...            3
# 20  {'id': 4, 'title': 'movies', 'created_at': '20...            4
# 21  {'id': 6, 'title': '"cat" egory', 'created_at'...            6
# 22  {'id': 1, 'title': 'politics', 'created_at': '...            1
# 23  {'id': 2, 'title': 'baseball', 'created_at': '...            2
# 24  {'id': 5, 'title': 'australia', 'created_at': ...            5
# 25  {'id': 6, 'title': '"cat" egory', 'created_at'...            6
# 26  {'id': 7, 'title': 'u.s. cities', 'created_at'...            7
# 27  {'id': 8, 'title': 'time', 'created_at': '2014...            8
# 28  {'id': 9, 'title': 'dining out', 'created_at':...            9
# 29  {'id': 10, 'title': 'children's literature', '...           10
# ..                                                ...          ...
# 70  {'id': 13, 'title': 'inventions', 'created_at'...           13
# 71  {'id': 14, 'title': 'ancient worlds', 'created...           14
# 72  {'id': 15, 'title': 'hollywood legends', 'crea...           15
# 73  {'id': 16, 'title': 'cars', 'created_at': '201...           16
# 74  {'id': 17, 'title': 'u.s. states', 'created_at...           17
# 75  {'id': 18, 'title': '"hard"', 'created_at': '2...           18
# 76  {'id': 13, 'title': 'inventions', 'created_at'...           13
# 77  {'id': 14, 'title': 'ancient worlds', 'created...           14
# 78  {'id': 15, 'title': 'hollywood legends', 'crea...           15
# 79  {'id': 17, 'title': 'u.s. states', 'created_at...           17
# 80  {'id': 18, 'title': '"hard"', 'created_at': '2...           18
# 81  {'id': 13, 'title': 'inventions', 'created_at'...           13
# 82  {'id': 14, 'title': 'ancient worlds', 'created...           14
# 83  {'id': 15, 'title': 'hollywood legends', 'crea...           15
# 84  {'id': 16, 'title': 'cars', 'created_at': '201...           16
# 85  {'id': 17, 'title': 'u.s. states', 'created_at...           17
# 86  {'id': 18, 'title': '"hard"', 'created_at': '2...           18
# 87  {'id': 20, 'title': 'comedians', 'created_at':...           20
# 88  {'id': 21, 'title': 'animals', 'created_at': '...           21
# 89  {'id': 22, 'title': 'number please', 'created_...           22
# 90  {'id': 23, 'title': 'awards', 'created_at': '2...           23
# 91  {'id': 24, 'title': 'movie trivia', 'created_a...           24
# 92  {'id': 19, 'title': 'landmarks', 'created_at':...           19
# 93  {'id': 20, 'title': 'comedians', 'created_at':...           20
# 94  {'id': 21, 'title': 'animals', 'created_at': '...           21
# 95  {'id': 22, 'title': 'number please', 'created_...           22
# 96  {'id': 23, 'title': 'awards', 'created_at': '2...           23
# 97  {'id': 24, 'title': 'movie trivia', 'created_a...           24
# 98  {'id': 19, 'title': 'landmarks', 'created_at':...           19
# 99  {'id': 20, 'title': 'comedians', 'created_at':...           20
#
#                   created_at game_id   id  invalid_count  \
# 0   2014-02-11T22:47:18.829Z    None    2            NaN
# 1   2014-02-11T22:47:18.841Z    None    3            NaN
# 2   2014-02-11T22:47:18.854Z    None    4            NaN
# 3   2014-02-11T22:47:18.867Z    None    5            NaN
# 4   2014-02-11T22:47:18.878Z    None    6            NaN
# 5   2014-02-11T22:47:18.889Z    None    7            NaN
# 6   2014-02-11T22:47:18.901Z    None    8            NaN
# 7   2014-02-11T22:47:18.912Z    None    9            NaN
# 8   2014-02-11T22:47:18.923Z    None   10            NaN
# 9   2014-02-11T22:47:18.934Z    None   11            NaN
# 10  2014-02-11T22:47:18.947Z    None   12            NaN
# 11  2014-02-11T22:47:18.959Z    None   13            NaN
# 12  2014-02-11T22:47:18.970Z    None   14            NaN
# 13  2014-02-11T22:47:18.981Z    None   15            NaN
# 14  2014-02-11T22:47:18.993Z    None   16            NaN
# 15  2014-02-11T22:47:19.004Z    None   17            NaN
# 16  2014-02-11T22:47:19.015Z    None   18            NaN
# 17  2014-02-11T22:47:19.026Z    None   19            NaN
# 18  2014-02-11T22:47:19.037Z    None   20            NaN
# 19  2014-02-11T22:47:19.049Z    None   21            NaN
# 20  2014-02-11T22:47:19.061Z    None   22            NaN
# 21  2014-02-11T22:47:19.084Z    None   24            NaN
# 22  2014-02-11T22:47:19.095Z    None   25            NaN
# 23  2014-02-11T22:47:19.107Z    None   26            NaN
# 24  2014-02-11T22:47:19.140Z    None   29            NaN
# 25  2014-02-11T22:47:19.151Z    None   30            NaN
# 26  2014-02-11T22:47:19.557Z    None   31            NaN
# 27  2014-02-11T22:47:19.570Z    None   32            NaN
# 28  2014-02-11T22:47:19.582Z    None   33            NaN
# 29  2014-02-11T22:47:19.595Z    None   34            NaN
# ..                       ...     ...  ...            ...
# 70  2014-02-11T22:47:20.528Z    None   73            NaN
# 71  2014-02-11T22:47:20.540Z    None   74            NaN
# 72  2014-02-11T22:47:20.551Z    None   75            NaN
# 73  2014-02-11T22:47:20.562Z    None   76            NaN
# 74  2014-02-11T22:47:20.573Z    None   77            NaN
# 75  2014-02-11T22:47:20.584Z    None   78            NaN
# 76  2014-02-11T22:47:20.595Z    None   79            NaN
# 77  2014-02-11T22:47:20.607Z    None   80            NaN
# 78  2014-02-11T22:47:20.618Z    None   81            NaN
# 79  2014-02-11T22:47:20.642Z    None   83            NaN
# 80  2014-02-11T22:47:20.653Z    None   84            NaN
# 81  2014-02-11T22:47:20.664Z    None   85            NaN
# 82  2014-02-11T22:47:20.675Z    None   86            NaN
# 83  2014-02-11T22:47:20.687Z    None   87            NaN
# 84  2014-02-11T22:47:20.699Z    None   88            NaN
# 85  2014-02-11T22:47:20.711Z    None   89            NaN
# 86  2014-02-11T22:47:20.723Z    None   90            NaN
# 87  2014-02-11T22:47:21.122Z    None   92            NaN
# 88  2014-02-11T22:47:21.133Z    None   93            NaN
# 89  2014-02-11T22:47:21.144Z    None   94            NaN
# 90  2014-02-11T22:47:21.156Z    None   95            NaN
# 91  2014-02-11T22:47:21.168Z    None   96            NaN
# 92  2014-02-11T22:47:21.181Z    None   97            NaN
# 93  2014-02-11T22:47:21.195Z    None   98            NaN
# 94  2014-02-11T22:47:21.207Z    None   99            NaN
# 95  2014-02-11T22:47:21.220Z    None  100            NaN
# 96  2014-02-11T22:47:21.232Z    None  101            NaN
# 97  2014-02-11T22:47:21.244Z    None  102            NaN
# 98  2014-02-11T22:47:21.255Z    None  103            NaN
# 99  2014-02-11T22:47:21.294Z    None  104            NaN
#
#                                              question  \
# 0   The Atlanta Braves are in this division of the...
# 1                 Eliza Doolittle did it for a living
# 2                    Subtitled "The Search for Spock"
# 3                  1 of 2 animals on its coat of arms
# 4   Malcolm McDowell & Nastassja Kinski's "purr"fe...
# 5   Traditionally speaking, as this state goes, "s...
# 6   Eddie Gaedel, number 1/8th, was the only one e...
# 7   In the Old West they were in charge of horses,...
# 8   Title describing Tom Cruise's precarious comme...
# 9   Title of this song, which actually means "to t...
# 10  Ancient weapon kept a stone's throw from its t...
# 11        "Shrill" name for train tour electioneering
# 12  Now a paper company sales rep, he pitched only...
# 13                He solemnly swears you in, in court
# 14  Film where Lily Tomlin is really Steve Martin'...
# 15  "Satanic" mammal found only on island S. of Au...
# 16        It gets things going in a chemical reaction
# 17  The rooster was symbol of this party before Th...
# 18        Boston's "Green Monster" is in this stadium
# 19  Ub Iwerks, Friz Freleng & Tex Avery drew the l...
# 20               Mozart's middle name becomes a movie
# 21  Elizabeth Taylor character that could have bur...
# 22  He called himself "the plain people's pres. ag...
# 23  In '84, he became 1st manager to win over 100 ...
# 24
# 25  During one in a hospital, your brain should th...
# 26  Alaskan city renamed this because ships docked...
# 27  Watch named for the vibrating crystal that run...
# 28  Shortened from French meaning "master of hotel...
# 29      Little girl who called "Sunnybrook Farm" home
# ..                                                ...
# 70  1899 device for attaching papers that can ruin...
# 71  Followed the Stone Age; named for copper alloy...
# 72  The 3 stars of "Rebel Without a Cause" who met...
# 73                                What BMW stands for
# 74             Only U.S. state with a "Z" in its name
# 75  Reason people used to stick a trumpet in their...
# 76  After inventing the lever & pulley, this Greek...
# 77  The Chinese once regarded calligraphy as a bra...
# 78  In her 1st film she sang with "Alfalfa" Switze...
# 79  The New England state without an Atlantic Ocea...
# 80              TV role Brian Keith judged OK to play
# 81  1st one to attempt sinking a warship was the "...
# 82  Civilization of sailors that developed 1st Wes...
# 83  Oliver Hardy's co-star in "The Fighting Kentuc...
# 84
# 85  8th state of the Union, it was the 1st state t...
# 86  Album & film featuring "Tell Me Why" & "You Ca...
# 87  Comic whose "Trial by Fire" fueled his comedy ...
# 88  "Sly" creature sought by sportsmen riding to h...
# 89
# 90          British decoration named for former queen
# 91               What Paul Newman's "Hustler" hustled
# 92  De"faced" by sand & invading armies, it crouch...
# 93  Master of the pause followed by "Now cut that ...
# 94                           The "ship of the desert"
# 95
# 96  Since '32 the U.S. Badge of Military Merit has...
# 97  Subtitled "How I Learned to Stop Worrying & Lo...
# 98        His statue is atop Philadelphia's City Hall
# 99  Pat Paulsen ran for president on their controv...
#
#                   updated_at  value
# 0   2014-02-11T22:47:18.829Z  100.0
# 1   2014-02-11T22:47:18.841Z  100.0
# 2   2014-02-11T22:47:18.854Z  100.0
# 3   2014-02-11T22:47:18.867Z  100.0
# 4   2014-02-11T22:47:18.878Z  100.0
# 5   2014-02-11T22:47:18.889Z  200.0
# 6   2014-02-11T22:47:18.901Z  200.0
# 7   2014-02-11T22:47:18.912Z  200.0
# 8   2014-02-11T22:47:18.923Z  200.0
# 9   2014-02-11T22:47:18.934Z    NaN
# 10  2014-02-11T22:47:18.947Z  200.0
# 11  2014-02-11T22:47:18.959Z  300.0
# 12  2014-02-11T22:47:18.970Z  300.0
# 13  2014-02-11T22:47:18.981Z  300.0
# 14  2014-02-11T22:47:18.993Z  300.0
# 15  2014-02-11T22:47:19.004Z  300.0
# 16  2014-02-11T22:47:19.015Z  300.0
# 17  2014-02-11T22:47:19.026Z  400.0
# 18  2014-02-11T22:47:19.037Z  400.0
# 19  2014-02-11T22:47:19.049Z  400.0
# 20  2014-02-11T22:47:19.061Z  400.0
# 21  2014-02-11T22:47:19.084Z  400.0
# 22  2014-02-11T22:47:19.095Z  500.0
# 23  2014-02-11T22:47:19.107Z  500.0
# 24  2014-02-11T22:47:19.140Z    NaN
# 25  2014-02-11T22:47:19.151Z  500.0
# 26  2014-02-11T22:47:19.557Z  100.0
# 27  2014-02-11T22:47:19.570Z  100.0
# 28  2014-02-11T22:47:19.582Z  100.0
# 29  2014-02-11T22:47:19.595Z  100.0
# ..                       ...    ...
# 70  2014-02-11T22:47:20.528Z  300.0
# 71  2014-02-11T22:47:20.540Z  300.0
# 72  2014-02-11T22:47:20.551Z    NaN
# 73  2014-02-11T22:47:20.562Z  300.0
# 74  2014-02-11T22:47:20.573Z  300.0
# 75  2014-02-11T22:47:20.584Z  300.0
# 76  2014-02-11T22:47:20.595Z  400.0
# 77  2014-02-11T22:47:20.607Z  400.0
# 78  2014-02-11T22:47:20.618Z  400.0
# 79  2014-02-11T22:47:20.642Z  400.0
# 80  2014-02-11T22:47:20.653Z  400.0
# 81  2014-02-11T22:47:20.664Z  500.0
# 82  2014-02-11T22:47:20.675Z  500.0
# 83  2014-02-11T22:47:20.687Z  500.0
# 84  2014-02-11T22:47:20.699Z    NaN
# 85  2014-02-11T22:47:20.711Z  500.0
# 86  2014-02-11T22:47:20.723Z  500.0
# 87  2014-02-11T22:47:21.122Z  100.0
# 88  2014-02-11T22:47:21.133Z  100.0
# 89  2014-02-11T22:47:21.144Z    NaN
# 90  2014-02-11T22:47:21.156Z  100.0
# 91  2014-02-11T22:47:21.168Z  100.0
# 92  2014-02-11T22:47:21.181Z  200.0
# 93  2014-02-11T22:47:21.195Z  200.0
# 94  2014-02-11T22:47:21.207Z  200.0
# 95  2014-02-11T22:47:21.220Z    NaN
# 96  2014-02-11T22:47:21.232Z  200.0
# 97  2014-02-11T22:47:21.244Z  200.0
# 98  2014-02-11T22:47:21.255Z  300.0
# 99  2014-02-11T22:47:21.294Z  300.0
#
# [100 rows x 11 columns]
